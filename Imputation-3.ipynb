# %%
import pandas as pd
import numpy as np

df = pd.read_csv('train_data.csv')

# %%
df.drop(columns=['PassengerId','Name','Cabin','Ticket'],inplace=True)

# %%
df
# Out:
#      Survived  Pclass     Sex   Age  SibSp  Parch     Fare Embarked
# 0           0       3    male  22.0      1      0   7.2500        S
# 1           1       1  female  38.0      1      0  71.2833        C
# 2           1       3  female  26.0      0      0   7.9250        S
# 3           1       1  female  35.0      1      0  53.1000        S
# 4           0       3    male  35.0      0      0   8.0500        S
# ..        ...     ...     ...   ...    ...    ...      ...      ...
# 886         0       2    male  27.0      0      0  13.0000        S
# 887         1       1  female  19.0      0      0  30.0000        S
# 888         0       3  female   NaN      1      2  23.4500        S
# 889         1       1    male  26.0      0      0  30.0000        C
# 890         0       3    male  32.0      0      0   7.7500        Q
#
# [891 rows x 8 columns]

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
sns.displot(df['Age'],kind='kde')

# %%
sns.boxplot(df['Age'])
# Out:
# <Axes: ylabel='Age'>

# %%
df.info()  # 714 missing values
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 8 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Survived  891 non-null    int64
#  1   Pclass    891 non-null    int64
#  2   Sex       891 non-null    object
#  3   Age       714 non-null    float64
#  4   SibSp     891 non-null    int64
#  5   Parch     891 non-null    int64
#  6   Fare      891 non-null    float64
#  7   Embarked  889 non-null    object
# dtypes: float64(2), int64(4), object(2)
# memory usage: 55.8+ KB

# %%
df['Age'].fillna(df['Age'].mean(), inplace=True)
# Mean Imputation: replace missing values in column 'A' with the mean of 'A'
# Out:
# C:\Users\Rohit\AppData\Local\Temp\ipykernel_1104\2422457112.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Age'].fillna(df['Age'].mean(), inplace=True)

# %%
df.info()  # 0 missing values
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 8 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Survived  891 non-null    int64
#  1   Pclass    891 non-null    int64
#  2   Sex       891 non-null    object
#  3   Age       891 non-null    float64
#  4   SibSp     891 non-null    int64
#  5   Parch     891 non-null    int64
#  6   Fare      891 non-null    float64
#  7   Embarked  889 non-null    object
# dtypes: float64(2), int64(4), object(2)
# memory usage: 55.8+ KB

# %%
#Same we can do the median imputation

## Median Imputation: replace missing values in column 'B' with the median of 'B'
#df['B'].fillna(df['B'].median(), inplace=True)

# %%
from sklearn.impute import SimpleImputer

# Initialize the SimpleImputer with mean strategy
si = SimpleImputer(strategy='mean')

# Apply mean imputation on the 'Age' column
mean_age1 = si.fit_transform(df[['Age']])
mean_age1


#u can directly do with the help of SimpleImputer from sklearn.impute
#same for median
# Out:
# array([[22.        ],
#        [38.        ],
#        [26.        ],
#        [35.        ],
#        [35.        ],
#        [29.69911765],
#        [54.        ],
#        [ 2.        ],
#        [27.        ],
#        [14.        ],
#        [ 4.        ],
#        [58.        ],
#        [20.        ],
#        [39.        ],
#        [14.        ],
#        [55.        ],
#        [ 2.        ],
#        [29.69911765],
#        [31.        ],
#        [29.69911765],
#        [35.        ],
#        [34.        ],
#        [15.        ],
#        [28.        ],
#        [ 8.        ],
#        [38.        ],
#        [29.69911765],
#        [19.        ],
#        [29.69911765],
#        [29.69911765],
#        [40.        ],
#        [29.69911765],
#        [29.69911765],
#        [66.        ],
#        [28.        ],
#        [42.        ],
#        [29.69911765],
#        [21.        ],
#        [18.        ],
#        [14.        ],
#        [40.        ],
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 8 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Survived  891 non-null    int64
#  1   Pclass    891 non-null    int64
#  2   Sex       891 non-null    object
#  3   Age       891 non-null    float64
#  4   SibSp     891 non-null    int64
#  5   Parch     891 non-null    int64
#  6   Fare      891 non-null    float64
#  7   Embarked  889 non-null    object
# dtypes: float64(2), int64(4), object(2)
# memory usage: 55.8+ KB

# %%
# Arbitary Value Imputaion

# %%
# # Arbitrary value imputation is a technique used to handle missing values in a dataset by replacing them with a specified value,
# #  often chosen arbitrarily. This approach can be helpful when you don’t want to remove rows or columns with missing values
# #  but still need a complete dataset for analysis or machine learning models.

# Arbitrary Value Selection: A common choice is to replace missing values with a fixed number, like -1, 0, or even an extreme value
#  (like 999) that clearly stands out as not being part of the usual data range.

# %%
df.isnull().mean()*100
# Out:
# Survived    0.000000
# Pclass      0.000000
# Sex         0.000000
# Age         0.000000
# SibSp       0.000000
# Parch       0.000000
# Fare        0.000000
# Embarked    0.224467
# dtype: float64

# %%
# Impute missing values in column 'A' with an arbitrary value -1
df['Age'].fillna(-1, inplace=True)
# Out:
# C:\Users\Rohit\AppData\Local\Temp\ipykernel_1104\759869610.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Age'].fillna(-1, inplace=True)
