# %%
import pandas as pd
df=pd.read_csv('train_data.csv')
df.head(10)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
# 6            7         0       1
# 7            8         0       3
# 8            9         1       3
# 9           10         1       2
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
# 5                                   Moran, Mr. James    male   NaN      0
# ...

# %%
df['Age']
# Out:
# 0      22.0
# 1      38.0
# 2      26.0
# 3      35.0
# 4      35.0
#        ...
# 886    27.0
# 887    19.0
# 888     NaN
# 889    26.0
# 890    32.0
# Name: Age, Length: 891, dtype: float64

# %%
from sklearn.preprocessing import StandardScaler

stand_scaler = StandardScaler()
stand_scaler.fit(df[['Age']])  # Step 1: Fit the scaler on the Age column
stand_scaler.transform(df[['Age']])  # Step 2: Transform the Age column and add it to the DataFrame
# Out:
# array([[-0.53037664],
#        [ 0.57183099],
#        [-0.25482473],
#        [ 0.36516706],
#        [ 0.36516706],
#        [        nan],
#        [ 1.67403863],
#        [-1.90813618],
#        [-0.18593675],
#        [-1.08148046],
#        [-1.77036023],
#        [ 1.94959054],
#        [-0.6681526 ],
#        [ 0.64071897],
#        [-1.08148046],
#        [ 1.74292661],
#        [-1.90813618],
#        [        nan],
#        [ 0.08961515],
#        [        nan],
#        [ 0.36516706],
#        [ 0.29627909],
#        [-1.01259248],
#        [-0.11704878],
#        [-1.49480832],
#        [ 0.57183099],
#        [        nan],
#        [-0.73704057],
#        [        nan],
#        [        nan],
#        [ 0.70960695],
#        [        nan],
#        [        nan],
#        [ 2.50069435],
#        [-0.11704878],
#        [ 0.8473829 ],
#        [        nan],
#        [-0.59926462],
#        [-0.80592855],
#        [-1.08148046],
#        [ 0.70960695],
# ...

# %%
df['Age'].describe()
# Out:
# count    714.000000
# mean      29.699118
# std       14.526497
# min        0.420000
# 25%       20.125000
# 50%       28.000000
# 75%       38.000000
# max       80.000000
# Name: Age, dtype: float64

# %%
df['Age'].std()
# Out:
# np.float64(14.526497332334042)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
df['Fare'].unique()
# Out:
# array([  7.25  ,  71.2833,   7.925 ,  53.1   ,   8.05  ,   8.4583,
#         51.8625,  21.075 ,  11.1333,  30.0708,  16.7   ,  26.55  ,
#         31.275 ,   7.8542,  16.    ,  29.125 ,  13.    ,  18.    ,
#          7.225 ,  26.    ,   8.0292,  35.5   ,  31.3875, 263.    ,
#          7.8792,   7.8958,  27.7208, 146.5208,   7.75  ,  10.5   ,
#         82.1708,  52.    ,   7.2292,  11.2417,   9.475 ,  21.    ,
#         41.5792,  15.5   ,  21.6792,  17.8   ,  39.6875,   7.8   ,
#         76.7292,  61.9792,  27.75  ,  46.9   ,  80.    ,  83.475 ,
#         27.9   ,  15.2458,   8.1583,   8.6625,  73.5   ,  14.4542,
#         56.4958,   7.65  ,  29.    ,  12.475 ,   9.    ,   9.5   ,
#          7.7875,  47.1   ,  15.85  ,  34.375 ,  61.175 ,  20.575 ,
#         34.6542,  63.3583,  23.    ,  77.2875,   8.6542,   7.775 ,
#         24.15  ,   9.825 ,  14.4583, 247.5208,   7.1417,  22.3583,
#          6.975 ,   7.05  ,  14.5   ,  15.0458,  26.2833,   9.2167,
# ...

# %%
stand_scaler = StandardScaler()
stand_scaler.fit(df[['Fare']]) 
stand_scaler.transform(df[['Fare']])
# Out:
# array([[-5.02445171e-01],
#        [ 7.86845294e-01],
#        [-4.88854258e-01],
#        [ 4.20730236e-01],
#        [-4.86337422e-01],
#        [-4.78116429e-01],
#        [ 3.95813561e-01],
#        [-2.24083121e-01],
#        [-4.24256141e-01],
#        [-4.29555021e-02],
#        [-3.12172378e-01],
#        [-1.13845709e-01],
#        [-4.86337422e-01],
#        [-1.87093118e-02],
#        [-4.90279793e-01],
#        [-3.26266659e-01],
#        [-6.19988892e-02],
#        [-3.86670720e-01],
#        [-2.85997284e-01],
#        [-5.02948539e-01],
#        [-1.24919787e-01],
#        [-3.86670720e-01],
#        [-4.86756223e-01],
#        [ 6.63597416e-02],
#        [-2.24083121e-01],
#        [-1.64441595e-02],
#        [-5.02948539e-01],
#        [ 4.64700108e+00],
#        [-4.89776426e-01],
#        [-4.89442190e-01],
#        [-9.02720170e-02],
#        [ 2.30172882e+00],
#        [-4.92377828e-01],
#        [-4.37007438e-01],
#        [ 1.00606170e+00],
# ...
