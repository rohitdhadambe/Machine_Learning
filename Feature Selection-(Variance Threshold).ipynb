# %%
import pandas as pd
df = pd.read_csv('Student Depression Dataset.csv')
df
# Out:
#            id  Gender   Age           City Profession  Academic Pressure  \
# 0           2    Male  33.0  Visakhapatnam    Student                5.0
# 1           8  Female  24.0      Bangalore    Student                2.0
# 2          26    Male  31.0       Srinagar    Student                3.0
# 3          30  Female  28.0       Varanasi    Student                3.0
# 4          32  Female  25.0         Jaipur    Student                4.0
# ...       ...     ...   ...            ...        ...                ...
# 27896  140685  Female  27.0          Surat    Student                5.0
# 27897  140686    Male  27.0       Ludhiana    Student                2.0
# 27898  140689    Male  31.0      Faridabad    Student                3.0
# 27899  140690  Female  18.0       Ludhiana    Student                5.0
# 27900  140699    Male  27.0          Patna    Student                4.0
#
#        Work Pressure  CGPA  Study Satisfaction  Job Satisfaction  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27901 entries, 0 to 27900
# Data columns (total 18 columns):
#  #   Column                                 Non-Null Count  Dtype
# ---  ------                                 --------------  -----
#  0   id                                     27901 non-null  int64
#  1   Gender                                 27901 non-null  object
#  2   Age                                    27901 non-null  float64
#  3   City                                   27901 non-null  object
#  4   Profession                             27901 non-null  object
#  5   Academic Pressure                      27901 non-null  float64
#  6   Work Pressure                          27901 non-null  float64
#  7   CGPA                                   27901 non-null  float64
#  8   Study Satisfaction                     27901 non-null  float64
#  9   Job Satisfaction                       27901 non-null  float64
# ...

# %%
# Imputation

# %%
df['Financial Stress'].skew()
# Out:
# np.float64(-0.13030399391268596)

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.distplot(df['Financial Stress'],hist=False)
# Out:
# C:\Users\Rohit\AppData\Local\Temp\ipykernel_10140\1673127395.py:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Financial Stress'],hist=False)
# <Axes: xlabel='Financial Stress', ylabel='Density'>

# %%
from sklearn.impute import SimpleImputer
imputer = SimpleImputer(strategy='mean')
df['Financial Stress'] = imputer.fit_transform(df[['Financial Stress']])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27901 entries, 0 to 27900
# Data columns (total 18 columns):
#  #   Column                                 Non-Null Count  Dtype
# ---  ------                                 --------------  -----
#  0   id                                     27901 non-null  int64
#  1   Gender                                 27901 non-null  object
#  2   Age                                    27901 non-null  float64
#  3   City                                   27901 non-null  object
#  4   Profession                             27901 non-null  object
#  5   Academic Pressure                      27901 non-null  float64
#  6   Work Pressure                          27901 non-null  float64
#  7   CGPA                                   27901 non-null  float64
#  8   Study Satisfaction                     27901 non-null  float64
#  9   Job Satisfaction                       27901 non-null  float64
# ...

# %%
# Encoding

# %%
df.drop(['id'], axis=1, inplace=True)
df
# Out:
#        Gender   Age           City Profession  Academic Pressure  \
# 0        Male  33.0  Visakhapatnam    Student                5.0
# 1      Female  24.0      Bangalore    Student                2.0
# 2        Male  31.0       Srinagar    Student                3.0
# 3      Female  28.0       Varanasi    Student                3.0
# 4      Female  25.0         Jaipur    Student                4.0
# ...       ...   ...            ...        ...                ...
# 27896  Female  27.0          Surat    Student                5.0
# 27897    Male  27.0       Ludhiana    Student                2.0
# 27898    Male  31.0      Faridabad    Student                3.0
# 27899  Female  18.0       Ludhiana    Student                5.0
# 27900    Male  27.0          Patna    Student                4.0
#
#        Work Pressure  CGPA  Study Satisfaction  Job Satisfaction  \
# 0                0.0  8.97                 2.0               0.0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27901 entries, 0 to 27900
# Data columns (total 17 columns):
#  #   Column                                 Non-Null Count  Dtype
# ---  ------                                 --------------  -----
#  0   Gender                                 27901 non-null  object
#  1   Age                                    27901 non-null  float64
#  2   City                                   27901 non-null  object
#  3   Profession                             27901 non-null  object
#  4   Academic Pressure                      27901 non-null  float64
#  5   Work Pressure                          27901 non-null  float64
#  6   CGPA                                   27901 non-null  float64
#  7   Study Satisfaction                     27901 non-null  float64
#  8   Job Satisfaction                       27901 non-null  float64
#  9   Sleep Duration                         27901 non-null  object
# ...

# %%
df.Profession.unique()
# Out:
# array(['Student', 'Civil Engineer', 'Architect', 'UX/UI Designer',
#        'Digital Marketer', 'Content Writer', 'Educational Consultant',
#        'Teacher', 'Manager', 'Chef', 'Doctor', 'Lawyer', 'Entrepreneur',
#        'Pharmacist'], dtype=object)

# %%
from sklearn.preprocessing import OneHotEncoder 
OHE=OneHotEncoder(sparse_output=False,dtype='int64',handle_unknown='ignore')
df['Profession']=OHE.fit_transform(df[['Profession']])

# %%
df['Sleep Duration'].unique()
# Out:
# array(['5-6 hours', 'Less than 5 hours', '7-8 hours', 'More than 8 hours',
#        'Others'], dtype=object)

# %%
from sklearn.preprocessing import OrdinalEncoder
OR= OrdinalEncoder(categories=[['Less than 5 hours', '5-6 hours', '7-8 hours', 'More than 8 hours', 'Others']])
df['Sleep Duration'] = OR.fit_transform(df[['Sleep Duration']])

# %%
df['Dietary Habits'].unique()
# Out:
# array(['Healthy', 'Moderate', 'Unhealthy', 'Others'], dtype=object)

# %%
health_status_encoder = OrdinalEncoder(categories=[['Healthy', 'Moderate', 'Unhealthy', 'Others']])
df['Dietary Habits'] = health_status_encoder.fit_transform(df[['Dietary Habits']])

# %%
df['Degree'].unique()
# Out:
# array(['B.Pharm', 'BSc', 'BA', 'BCA', 'M.Tech', 'PhD', 'Class 12', 'B.Ed',
#        'LLB', 'BE', 'M.Ed', 'MSc', 'BHM', 'M.Pharm', 'MCA', 'MA', 'B.Com',
#        'MD', 'MBA', 'MBBS', 'M.Com', 'B.Arch', 'LLM', 'B.Tech', 'BBA',
#        'ME', 'MHM', 'Others'], dtype=object)

# %%
OHE1=OneHotEncoder(sparse_output=False,dtype='int64',handle_unknown='ignore')
df['Degree']=OHE1.fit_transform(df[['Degree']])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27901 entries, 0 to 27900
# Data columns (total 17 columns):
#  #   Column                                 Non-Null Count  Dtype
# ---  ------                                 --------------  -----
#  0   Gender                                 27901 non-null  object
#  1   Age                                    27901 non-null  float64
#  2   City                                   27901 non-null  object
#  3   Profession                             27901 non-null  int64
#  4   Academic Pressure                      27901 non-null  float64
#  5   Work Pressure                          27901 non-null  float64
#  6   CGPA                                   27901 non-null  float64
#  7   Study Satisfaction                     27901 non-null  float64
#  8   Job Satisfaction                       27901 non-null  float64
#  9   Sleep Duration                         27901 non-null  float64
# ...

# %%
df['Have you ever had suicidal thoughts ?'].unique()
# Out:
# array(['Yes', 'No'], dtype=object)

# %%
from sklearn.preprocessing import LabelEncoder
label_encoder = LabelEncoder()
df['Have you ever had suicidal thoughts ?'] = label_encoder.fit_transform(df['Have you ever had suicidal thoughts ?'])

# %%
df['Family History of Mental Illness'].unique()
# Out:
# array(['No', 'Yes'], dtype=object)

# %%
from sklearn.preprocessing import LabelEncoder
label_encoder = LabelEncoder()
df['Family History of Mental Illness'] = label_encoder.fit_transform(df['Family History of Mental Illness'])

# %%
df['Gender'].unique()
# Out:
# array(['Male', 'Female'], dtype=object)

# %%
from sklearn.preprocessing import OneHotEncoder 
OHE=OneHotEncoder(sparse_output=False,dtype='int64',handle_unknown='ignore')
df['Gender']=OHE.fit_transform(df[['Gender']])

# %%
df['City'].unique()
# Out:
# array(['Visakhapatnam', 'Bangalore', 'Srinagar', 'Varanasi', 'Jaipur',
#        'Pune', 'Thane', 'Chennai', 'Nagpur', 'Nashik', 'Vadodara',
#        'Kalyan', 'Rajkot', 'Ahmedabad', 'Kolkata', 'Mumbai', 'Lucknow',
#        'Indore', 'Surat', 'Ludhiana', 'Bhopal', 'Meerut', 'Agra',
#        'Ghaziabad', 'Hyderabad', 'Vasai-Virar', 'Kanpur', 'Patna',
#        'Faridabad', 'Delhi', 'Saanvi', 'M.Tech', 'Bhavna', 'Less Delhi',
#        'City', '3.0', 'Less than 5 Kalyan', 'Mira', 'Harsha', 'Vaanya',
#        'Gaurav', 'Harsh', 'Reyansh', 'Kibara', 'Rashi', 'ME', 'M.Com',
#        'Nalyan', 'Mihir', 'Nalini', 'Nandini', 'Khaziabad'], dtype=object)

# %%
from sklearn.preprocessing import OneHotEncoder 
OHE=OneHotEncoder(sparse_output=False,dtype='int64',handle_unknown='ignore')
df['City']=OHE.fit_transform(df[['City']])

# %%
df
# Out:
#        Gender   Age  City  Profession  Academic Pressure  Work Pressure  CGPA  \
# 0           0  33.0     0           0                5.0            0.0  8.97
# 1           1  24.0     0           0                2.0            0.0  5.90
# 2           0  31.0     0           0                3.0            0.0  7.03
# 3           1  28.0     0           0                3.0            0.0  5.59
# 4           1  25.0     0           0                4.0            0.0  8.13
# ...       ...   ...   ...         ...                ...            ...   ...
# 27896       1  27.0     0           0                5.0            0.0  5.75
# 27897       0  27.0     0           0                2.0            0.0  9.40
# 27898       0  31.0     0           0                3.0            0.0  6.61
# 27899       1  18.0     0           0                5.0            0.0  6.88
# 27900       0  27.0     0           0                4.0            0.0  9.24
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27901 entries, 0 to 27900
# Data columns (total 17 columns):
#  #   Column                                 Non-Null Count  Dtype
# ---  ------                                 --------------  -----
#  0   Gender                                 27901 non-null  int64
#  1   Age                                    27901 non-null  float64
#  2   City                                   27901 non-null  int64
#  3   Profession                             27901 non-null  int64
#  4   Academic Pressure                      27901 non-null  float64
#  5   Work Pressure                          27901 non-null  float64
#  6   CGPA                                   27901 non-null  float64
#  7   Study Satisfaction                     27901 non-null  float64
#  8   Job Satisfaction                       27901 non-null  float64
#  9   Sleep Duration                         27901 non-null  float64
# ...

# %%
# standardisation and normalisation

# %%
from sklearn.preprocessing import StandardScaler

numerical_cols = [
    col for col in df.columns 
    if df[col].dtype in ['float64', 'int64'] and col not in ['id', 'Profession', 'Degree', 
                                                             'Have you ever had suicidal thoughts ?',
                                                             'Family History of Mental Illness', 'Depression']
]

# %%
scaler = StandardScaler()


# Fit and transform the numerical columns
df[numerical_cols] = scaler.fit_transform(df[numerical_cols])

# %%
df
# Out:
#          Gender       Age      City  Profession  Academic Pressure  \
# 0     -0.891416  1.463165 -0.005987           0           1.345543
# 1      1.121811 -0.371474 -0.005987           0          -0.826104
# 2     -0.891416  1.055467 -0.005987           0          -0.102222
# 3      1.121811  0.443921 -0.005987           0          -0.102222
# 4      1.121811 -0.167625 -0.005987           0           0.621660
# ...         ...       ...       ...         ...                ...
# 27896  1.121811  0.240073 -0.005987           0           1.345543
# 27897 -0.891416  0.240073 -0.005987           0          -0.826104
# 27898 -0.891416  1.055467 -0.005987           0          -0.102222
# 27899  1.121811 -1.594566 -0.005987           0           1.345543
# 27900 -0.891416  0.240073 -0.005987           0           0.621660
#
#        Work Pressure      CGPA  Study Satisfaction  Job Satisfaction  \
# 0          -0.009777  0.893393           -0.693425          -0.01534
# ...

# %% [markdown]
# # Feature Selection

# %%
numerical_colss = df.columns.tolist()  # bunch the all coloums

# %%
from sklearn.feature_selection import VarianceThreshold
fe=VarianceThreshold(threshold=0.1)

selected_features = fe.fit_transform(df[numerical_colss])
mask = fe.get_support()


# Retrieve the names of selected features
selected_feature_names = [col for col, is_selected in zip(numerical_colss, mask) if is_selected]


# Create a new dataframe with the selected features
df_selected = pd.DataFrame(selected_features, columns=selected_feature_names, index=df.index)

# %%
variances = pd.Series(fe.fit(df[numerical_colss]).variances_, index=numerical_colss)
print(variances)
# Out:
# Gender                                   1.000000
# Age                                      1.000000
# City                                     1.000000
# Profession                               0.000287
# Academic Pressure                        1.000000
# Work Pressure                            1.000000
# CGPA                                     1.000000
# Study Satisfaction                       1.000000
# Job Satisfaction                         1.000000
# Sleep Duration                           1.000000
# Dietary Habits                           1.000000
# Degree                                   0.050167
# Have you ever had suicidal thoughts ?    0.232362
# Work/Study Hours                         1.000000
# Financial Stress                         1.000000
# Family History of Mental Illness         0.249743
# Depression                               0.242690
# dtype: float64

# %%
print("Original Data Shape:", df[numerical_colss].shape)
print("Selected Data Shape:", df_selected.shape)
# Out:
# Original Data Shape: (27901, 17)
# Selected Data Shape: (27901, 15)

# %%
# Get the original column names
original_columns = df.columns.tolist()

# Get the names of the selected columns
selected_columns = [col for col, is_selected in zip(original_columns, fe.get_support()) if is_selected]

# Find the removed columns by comparing the original and selected columns
removed_columns = list(set(original_columns) - set(selected_columns))

print("Removed Columns:", removed_columns)
# Out:
# Removed Columns: ['Profession', 'Degree']

# %% [markdown]
#  Model selection == logistic regression

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression



X = df.drop(columns=['Depression'])  # Features (all columns except target)
y = df['Depression']               # Target variable


X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=420)


model = LogisticRegression()
model.fit(X_train, y_train)

# When you use solver='liblinear',
# you're telling the model to use this fast, efficient method to find the best parameters for binary classification problems.

# class_weight='balanced' is useful when you have imbalanced classes, as it adjusts the model 
# to pay more attention to the minority class.

y_pred = model.predict(X_test)

# %%
from sklearn.metrics import accuracy_score
accuracy_score(y_test,y_pred)
# Out:
# 0.8471600071671743
