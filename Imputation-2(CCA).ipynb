# %%
import pandas as pd
import numpy as np
df = pd.read_csv('data_science_job.csv')

# %%
df
# Out:
#        enrollee_id      city  city_development_index gender  \
# 0             8949  city_103                   0.920   Male
# 1            29725   city_40                   0.776   Male
# 2            11561   city_21                   0.624    NaN
# 3            33241  city_115                   0.789    NaN
# 4              666  city_162                   0.767   Male
# ...            ...       ...                     ...    ...
# 19153         7386  city_173                   0.878   Male
# 19154        31398  city_103                   0.920   Male
# 19155        24576  city_103                   0.920   Male
# 19156         5756   city_65                   0.802   Male
# 19157        23834   city_67                   0.855    NaN
#
#            relevent_experience enrolled_university education_level  \
# 0      Has relevent experience       no_enrollment        Graduate
# 1       No relevent experience       no_enrollment        Graduate
# ...

# %%
 df.dropna(subset=['enrolled_university','education_level','experience','training_hours'])

# The df.dropna() function in pandas is used to remove rows or columns with missing values (NaNs) from a DataFrame. Here’s how it works:

# By default, df.dropna() removes any row that has at least one missing value.
# You can also choose to remove columns with missing values by adding axis=1 like this: df.dropna(axis=1).
# If you only want to drop rows or columns where all values are missing, use how='all'.

#df.dropna(subset=['enrolled_university','education_level','experience','training_hours'],how='all')

#this is quit about CCA (complte case analysis)-->directly removing the rows
# Out:
#        enrollee_id      city  city_development_index gender  \
# 0             8949  city_103                   0.920   Male
# 1            29725   city_40                   0.776   Male
# 2            11561   city_21                   0.624    NaN
# 4              666  city_162                   0.767   Male
# 5            21651  city_176                   0.764    NaN
# ...            ...       ...                     ...    ...
# 19153         7386  city_173                   0.878   Male
# 19154        31398  city_103                   0.920   Male
# 19155        24576  city_103                   0.920   Male
# 19156         5756   city_65                   0.802   Male
# 19157        23834   city_67                   0.855    NaN
#
#            relevent_experience enrolled_university education_level  \
# 0      Has relevent experience       no_enrollment        Graduate
# 1       No relevent experience       no_enrollment        Graduate
# ...

# %%
# dropping rows directly from colmns

# %%
df.columns
# Out:
# Index(['enrollee_id', 'city', 'city_development_index', 'gender',
#        'relevent_experience', 'enrolled_university', 'education_level',
#        'major_discipline', 'experience', 'company_size', 'company_type',
#        'training_hours', 'target'],
#       dtype='object')

# %%
cols=[col for col in df.columns if df[col].isnull().mean()<0.05 and df[col].isnull().mean()>0]
#This line of code is selecting columns in a DataFrame (df) that have a small percentage of missing values.

# %%
df1=df[cols].dropna()  # dropping rows directly from colmns where there are null values

# %%
df1.isnull().mean()*100  # cheacking
# Out:
# city_development_index    0.0
# enrolled_university       0.0
# education_level           0.0
# experience                0.0
# training_hours            0.0
# dtype: float64

# %%
#but We'll never use this scrap name CCA It would be crucial for data loss
# CCA It is nothing but removing the rows from the data set where there are less missing value
